# %%
/************************************
三范式:
    第一范式:对属性的原子性（相对性，比如姓名就没必要再分），即不可再分
            查询难度加大
            字段分开
    第二范式:
            数据冗余，修改困难
            表分开

*************************************/

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 不符合第一范式案例

# %% [markdown]
# ![image.png](attachment:image.png)
# 不符合第二范式，刘备出现在了两行，英语也出现了两次
