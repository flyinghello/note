# %% [markdown]
# 1. 测试前根据数模国赛tex模板，制作一个数模国赛tex的基础版，有摘要，问题重述、问题分析、模型的假设、符号说明、模型的建立与求解、模型的评价、模型的推广、参考文献、附录等。其中摘要含标题、关键词，单独占一页，摘要内容写班级姓名学号，关键词随便写。问题重述中要含有子标题，子标题内容自定。其他模块，比如问题分析等等，只要标题即可。基础版能生成pdf文件。
#
# 2. 当场寻找2张照片，并排插入，自动编号，有标题
#
# 3. 当场制作表格，插入，自动编号，有标题
#
# 4. 当场输入2个数学公式，居中，自动编号
#
# 5. 当场从图书馆网页进入知网，根据关键词（自己设定）查找期刊文献、查找硕博士论文，随便各找一篇，下载pdf文档，在tex文件中写入参考文献，并在正文中对应位置（测试时对应位置随便找）写上标。
#
# 6. 当场在附录中插入代码，代码自备。

# %% [markdown]
# # 特殊字符
# ```Latex
# 空表字符：用a \quad b 来实现
# 两个空格：用a \qquad b 来实现
#
# ```
